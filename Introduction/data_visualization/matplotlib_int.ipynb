# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ```python
#
# fig = plt.figure() # create a plot figure
# ax = plt.axes() # create axes of a plot
# ```
#
# fig is responsible for the overall appearance of the plot, and axes is responsible for the plotting region within the figure.

# %% [markdown]
# ```python
#
# plt.style.available # list of available styles
#
# ```

# %%
plt.style.use('bmh')
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes() # ax is == axis object
x = np.linspace(0, 10, 1000) # 1000 points between 0 and 10
y = np.sin(x) # y is the sin of x
ax.plot(x, np.sin(x)) # ax.plot is doing an intersection with the axes object, x[0] and y[0] are the first points of the line
plt.plot(x, y) # plt.plot is doing an intersection with the axes object, x[0] and y[0] are the first points of the line
# the first argument is the x axis, the second is the y axis, representing the axle of the graph.

# %%
fig = plt.figure()
ax = plt.axes()

plt.xlabel('Value')
plt.ylabel('Cos Value')
plt.title('Cosine Graph')

x = np.linspace(0, 10, 1000)
y = np.cos(x)
ax.plot(x,y)

# %% [markdown]
# ## Legends and Titles
#
# ```python
#
# ax.set(xlim=(0, 10), ylim=(-2, 2), # set the x and y limits of the plot
#        xlabel='x', ylabel='sin(x)', # set the x and y labels
#        title='A Simple Plot') # set the title of the plot
# ```
#
# ```python
#
# ax.legend(loc='upper left', frameon=False) # add a legend
# ```
#
# ```python
#
# ax.plot(x, np.sin(x), '-g', label='sin(x)') # add a label to the plot
# ```
#
# ```python
#
# ax.plot(x, np.cos(x), '--b', label='cos(x)') # add a label to the plot
# ```
#
# To we add a legend, we must use label keyword in the plot function.

# %%
fig = plt.figure()
ax = plt.axes()

N = np.linspace(0, 10, 1000)
x = np.cos(N)
y = np.sin(N)

plt.xlabel('Lenght of space N')
plt.ylabel('Value')

subtitle = ['Cosine Waves', 'Sin Waves'] # subtitle is a list of strings


plt.plot(N, x, label=subtitle[0])
plt.plot(N, y, label=subtitle[1])

plt.title('Cosine and Sine Waves') 
plt.legend(loc='lower left') # loc is the location of the legend
plt.show()

# %% [markdown]
# ## Colors and Styles
#
# ```python
#
# ax.plot(x, np.sin(x - 0), color='blue') # specify color by name
# ```
#
# ```python
#
# ax.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
# ```
#
# ```python
#
# ax.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
# ```
#
# ```python
#
# ax.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
# ```
#
# ```python
#
# ax.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1 # The first value is for red, the second for green, and the third for blue; the combination of these three colors makes up the gamut of visible colors.
# ```
#
# ```python
#
# ax.plot(x, np.sin(x - 5), color='chartreuse') # all HTML color names supported
# ```
#
# ### Line Styles
#
# ```python
#
# ax.plot(x, x + 0, linestyle='solid') # solid
# ```
#
# ```python
#
# ax.plot(x, x + 1, linestyle='dashed') # dashed
# ```
#
# ```python
#
# ax.plot(x, x + 2, linestyle='dashdot') # dashdot
# ```
#
# ```python
#
# ax.plot(x, x + 3, linestyle='dotted') # dotted
# ```
#
# ```python
#
# ax.plot(x, x + 4, linestyle='-') # solid
# ```
#
# ```python
#
# ax.plot(x, x + 5, linestyle='--') # dashed
# ```
#
# ```python
#
# ax.plot(x, x + 6, linestyle='-.') # dashdot
# ```
#
# ```python
#
# ax.plot(x, x + 7, linestyle=':') # dotted
# ```
#
# ## Union of color and style
#
# ```python
#
# ax.plot(x, x + 0, '-g') # solid green
# ```
#
# ```python
#
# ax.plot(x, x + 1, '--c') # dashed cyan
# ```
#
# ```python
#
# ax.plot(x, x + 2, '-.k') # dashdot black
# ```
#
# ```python
#
# ax.plot(x, x + 3, ':r') # dotted red
# ```
#
# ## Line Width
#
# ```python
#
# ax.plot(x, x + 0, '-g', linewidth=1.0)
# ```
#
# ```python
#
# ax.plot(x, x + 1, '-g', linewidth=2.0)
# ```
#
# ```python
#
# ax.plot(x, x + 2, '-g', linewidth=4.0)
# ```
#
# ```python
#
# ax.plot(x, x + 3, '-g', linewidth=8.0)
# ```

# %%
from turtle import color


N = np.linspace(0, 10, 1000)
x = 500+(np.cos(N))
y = np.cos(N)

plt.xlabel('Lenght of space N')
plt.ylabel('Value')

subtitle = ['Cosine Waves when we add 500', 'Cosine Waves'] # subtitle is a list of strings

plt.title('Cosine and Cosine add 500')

plt.plot(N, x, label=subtitle[0], color='red', linestyle='--')
plt.plot(N, y, label=subtitle[1], color='chartreuse', linestyle='dotted')

plt.legend(loc='best') # loc is the location of the legend

plt.show() # show the graph

# %%
from numpy import arccos


fig = plt.figure()
ax = plt.axes()

N = np.linspace(0, 10, 100)
sin_ = np.sin(N)
cos_ = np.cos(N)
arc_sin_ = np.arcsin(N)
arc_cos_ = np.arccos(N)

subtitles = ['Sine Wave', 'Cosine Wave', 'Arc Sin Wave', 'Arc Cos Wave']

plt.xlabel('Lenght of space N')
plt.ylabel('Value')

plt.plot(N, sin_, label=subtitles[0], color='green', linestyle='dotted')
plt.plot(N, cos_, label=subtitles[1], color='red', linestyle='-')
plt.plot(N, arc_sin_, label=subtitles[2], color='orange', linestyle='--')
plt.plot(N, arc_cos_, label=subtitles[3], color='blue', linestyle='-.')


plt.legend(loc='lower left')
plt.title('Sine, Cosine, Arc Cosine And Arc Sin Waves')

plt.show()
# Out:
# /tmp/ipykernel_27644/1847144489.py:10: RuntimeWarning: invalid value encountered in arcsin
#   arc_sin_ = np.arcsin(N)
# /tmp/ipykernel_27644/1847144489.py:11: RuntimeWarning: invalid value encountered in arccos
#   arc_cos_ = np.arccos(N)

# %% [markdown]
# ## Axis limits
#
# ### Difference beetwen plt.axis() and ax.axis():
#
# Axes objects have a number of attributes that can be used to customize the appearance of the plot: for example, set_xlim() and set_ylim() to set the plot limits on each of the axes.
#
# The axes belong to layout and all that stuff.
#
# Axis is basically the x and y axis that we see in the plot.
#
# ```python
#
# plt.axis([0, 10, -1, 1]) # [xmin, xmax, ymin, ymax]
# ```
#
# ```python
#
# ax.axis('tight') # automatically tighten the bounds around the current plot
# ```
#
# ```python
#
# ax.axis('equal') # ensure an equal aspect ratio so that on your screen, one unit in x is equal to one unit in y
# ```
#
# ```python
# plt.xlim(-10, 10) # set the x limits
# plt.ylim(-1, 1) # set the y limits
# plt.axis([-10,10, -1, 1]) # set the x and y limits
# ```
#
# ```python
# ```
#
# ```python
# ```

# %%
plt.figure(figsize=(4,2), dpi=90) # dpi is the resolution of the graph

plt.plot(N, sin_, label=subtitles[0], color='green', linestyle='dotted')
plt.plot(N, cos_, label=subtitles[1], color='red', linestyle='-', linewidth=0.5)

plt.xlim(-10, 20) # xlim is the x axis limit
plt.ylim(-2, 2) # ylim is the y axis limit

plt.legend(loc='lower left')
plt.title('Sine Wave')

plt.show()

# %%
plt.figure(figsize=(4,2), dpi=90) # dpi is the resolution of the graph

plt.plot(N, sin_, label=subtitles[0], color='green', linestyle='dotted')
plt.plot(N, cos_, label=subtitles[1], color='red', linestyle='-', linewidth=0.5)

plt.axis([-10, 20, -2, 2]) # axis is the x and y axis limit
plt.axis('tight') # tight will make the graph fit the data
plt.axis('equal') # equal make the graph fit the data

plt.legend(loc='lower left')
plt.title('Sine Wave')

plt.show()

# %% [markdown]
# ## Set functions
#
# ```python
#
# plt.xlabel() → ax.set_xlabel()
# ```
#
# ```python
#
# plt.ylabel() → ax.set_ylabel()
# ```
#
# ```python
#
# plt.xlim() → ax.set_xlim()
# ```
#
# ```python
#
# plt.ylim() → ax.set_ylim()
# ```
#
# ```python
#
# plt.title() → ax.set_title()
# ```
#
# There's another way too:
#
# ```python
#
# ax = plt.axes()
# ax.plot(x, np.sin(x))
# ax.set(xlim=(0,10), ylim=-2,2, xlabel='x', ylabel='sin(x)', title='A Simple Plot')
# ```

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.figure(figsize=(5,3), dpi=90) 
ax = plt.axes()
ax.plot(x, y)
ax.set(xlim=(-10,25), ylim=(-2,2), xlabel='x', ylabel='sin(x)', title='A Simple Plot')
# Out:
# [(-10.0, 25.0),
#  (-2.0, 2.0),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'sin(x)'),
#  Text(0.5, 1.0, 'A Simple Plot')]

# %% [markdown]
# ## Markers
#
# ```python
#
# # The markers avaliable are [+, o, *, s, <, >, ^, v, x, . , ',']
# # they were used in the same way as the line styles
# ax.plot(x, x + 5, marker='+')
# ```
#
# ```python
#
# ax.plot(x, x + 5, marker='o')
# ```
#
# ```python
#
# ax.plot(x, x + 5, marker='*')
# ```
#
# ```python
#
# ax.plot(x, x + 5, 's')
# ```
#
# ```python
#
# plt.plot(x,y, 'o', color='black')
# ```
# ### Line and marker styles together
#
# ```python
#
# plt.plot(x, y, '-ok') # solid black line with circle markers
# ```
#
# ```python
#
# plt.plot(x, y, '-p', color='gray', markersize=15, linewidth=4, markerfacecolor='white', markeredgecolor='gray', markeredgewidth=2) # gray dashed line with circle markers
# # markersize → size of the markers
# # markerfacecolor → color inside the marker
# # markeredgecolor → color of the marker edge
# # markeredgewidth → width of the marker edge
#
# ```

# %%
x = np.linspace(0, 10, 10) # the less the number of points, the more the markers will be visible, because the number of points is the number of markers
y = np.sin(x)
plt.figure(figsize=(5,3), dpi=90)
plt.plot(x, y, marker='s', linewidth=.5, markersize=7, color='red', linestyle=':')

# %%
markers_avaliable = ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd', 'p', '*', 'h', 'H', '1', '2', '3', '4', '8', 'D', 'P', 'X']


for marker in markers_avaliable:
    plt.figure(figsize=(5,3), dpi=90)
    plt.plot(x, y, marker=marker, label="marker='{0}'".format(marker), markersize=15) #.format is used to format the string with the marker
    plt.legend(loc='lower left')
    plt.title(f'Marker {marker}')
    plt.show()
