# %% [markdown]
# # Exercises

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Make a plot with using matplotlib:

#  x: 0 to 20 and generate 1500 values
#  y: cos of x
#  figure size 6x4
#  style 'seaborn-talk'
#  line color = orange
#  line style = dashed
# do not use axis command


# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

fig = plt.figure(figsize=(6,4))

x = np.linspace(0, 20, 1500)
y = np.cos(x)

plt.style.use('seaborn-talk')
plt.plot(x, y, color='orange', linestyle='dashed')
# Out:
# /tmp/ipykernel_60999/3230769763.py:21: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')

# %%
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Take the same plot and do the following:

"""
set x limit of 1 to 14
set y limit of -1 to 1.2

set x label to 'x'
set y label to 'cos(x)'

set title to 'Cosine function'

set the color to red
set the line width to 1.5
set the line style to dotted

now reverse the plot at y axis
DO not use axis command

"""

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(6,4))

plt.xlim(1, 14)
plt.ylim(-1, 1.2)

plt.xlabel('X')
plt.ylabel('Cos(x)')

plt.title('Cosine function')

plt.ylim(1.2, -1) # reversed y plot
plt.plot(x, y, color='red', linestyle='dotted',linewidth=1.5,)

# %%
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Take the same plot and do the following:

"""

Now do the same task using set command

Set x and y labels

"""

fig = plt.figure(figsize=(6,4))
ax = plt.axes()

x = np.linspace(0, 20, 1500)
y = np.cos(x)

plt.style.use('seaborn-talk')

ax.plot(x,y)
ax.set(xlim=(1, 14), ylim=(-1, 1.2), xlabel='X', ylabel='Cos(x)', title='Cosine function')
# Out:
# /tmp/ipykernel_60999/947873170.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')
# [(1.0, 14.0),
#  (-1.0, 1.2),
#  Text(0.5, 0, 'X'),
#  Text(0, 0.5, 'Cos(x)'),
#  Text(0.5, 1.0, 'Cosine function')]

# %%
"""

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

Make a Contour plot. Use X and Y points making a meshgrid with linspace function. Generate 50 values for X and 80 values for y from 5-10

For Z take this function: f = X+ (3*Y)*9*X

Use inferno colormap

Set number of intervals to 40

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
"""

x = np.linspace(5, 10, 50)
y = np.linspace(5, 10, 80)

X,Y = np.meshgrid(x,y)

Z = X+(3*Y)*9*X

plt.contourf(X,Y,Z, 40, cmap='inferno')
plt.colorbar()

# %%
"""
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

Generate subplots having 2 rows and 4 columns. There should be 8 plots in total. 
Set the color map to coolwarm.

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
"""



fig, ax = plt.subplots(2, 4, figsize=(4, 3), sharex='col', sharey='row')

for i in range(2):
    for j in range(4):
        ax[i,j].imshow(np.random.rand(255, 255), cmap='coolwarm')
        ax[i,j].set(xticks=[], yticks=[]) # remove ticks and labels

# %%
"""
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

Make 2 scatter plots

For first plot:

X,Y,Z (0,5, 50) Marker = '.' Color = green

For second plot:

X,Y,Z (10, 9, 70) Marker = '+' Color = yellow

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
"""

from mpl_toolkits.mplot3d import Axes3D # Axes3D is used to create 3D plots

fig = plt.figure(figsize=(6,4))
ax = plt.axes(projection='3d')

X = np.random.normal(0,5,50)
Y = np.random.normal(0,5,50)
Z = np.random.normal(0,5,50)

ax.scatter(X, Y, Z, marker='.', color='green')

X = np.random.normal(10,9,70)
Y = np.random.normal(10,9,70)
Z = np.random.normal(10,9,70)

ax.scatter(X, Y, Z, marker='+', color='yellow')

# %% [markdown]
# ## Seaborn

# %%
""" 

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

Make a relationship plot using iris data set:

-   X = sepal width
-   Y = petal length
-   Use sepal length for hue
-   Use species for style

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

"""

import seaborn as sns

iris = sns.load_dataset("iris")

sns.relplot(x='sepal_width', y='petal_length', hue='sepal_length', style='species', data=iris,)
# Out:
# /home/pcmoraes/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
"""
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
Make a relationship plot with tips dataset and do the following:

Take size as x and total_bill as y

Divide the columns by smoker category

Set hue and style to the sex

"""

tips = sns.load_dataset("tips")

sns.relplot(x='size', y='total_bill', col='smoker', hue='sex', style='sex' , data=tips)
# Out:
# /home/pcmoraes/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Bokeh

# %%
"""   
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
Make a grid plot with 4 plots (p1,p2,p3,p4)

y = use np.linspace with starting value 5, ending 20 and 30 values
x1 = sin(y)
x2 = cos(y)
x3 = x2 + x1 -1
x4 = y+2+(x2*x3)

make p1 a line with x1 and y cordinates (color green)
make p2 with marker circle and use x2 and y cordinates (color navy)
make p3 with marker triangle and use x3 and y cordinates (color red)
make p4 with marker square and use x4 and y cordinates (color black)

Set the label and titles 'Bokeh Practice 1, 2, 3 and 4 ' for all plots
Also set the size of markers to 8. Use output_notebook() to show the plot in notebook

# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
"""

from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import gridplot
output_notebook()

y = np.linspace(5, 20, 30)
x1 = np.sin(y)
x2 = np.cos(y)
x3 = x2 + x1 -1
x4 = y+2+(x2*x3)

p1 = figure(width=250, height=250, title='Bokeh Practice 1')
p1.line(y, x1, color='green', line_width=2)

p2 = figure(width=250, height=250, title='Bokeh Practice 2')
p2.circle(y, x2, color='navy', size=8)

p3 = figure(width=250, height=250, title='Bokeh Practice 3')
p3.triangle(y, x3, color='red', size=8)

p4 = figure(width=250, height=250, title='Bokeh Practice 4')
p4.square(y, x4, color='black', size=8)

p = gridplot([[p1, p2], [p3, p4]])

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c00cd99d-5fe6-4052-b788-2cab9fb2396c">Loading BokehJS ...</span>
#     </div>
#   <div id="efe72139-18a2-4382-935c-a68126b4ca11" data-root-id="p1501" style="display: contents;"></div>
