# %% [markdown]
# # RV in Real Data Sets

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('datas/Bias_correction_ucl.csv')
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# One random variable is sepal length, sepal width, petal_lenth, petal_width. The other random variable is the species of the flower.

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()

iris['species'] = labelencoder.fit_transform(iris['species'])

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# Here we transform a categorical variable (species) to a numerical variable (0, 1, 2) and then plot the joint distribution of the two random variables.

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# survived is a bernoulli random variable. It takes value 1 if the passenger survived and 0 if the passenger died.
#
# pclass is a discrete variable that takes values 1, 2, 3. It is the class of the passenger.
#
# We can do the same as species to sex and remove the categorical variable to a numerical variable.
#
# Fare isnt a discrete variable. It is a continuous variable. We can plot the joint distribution of the two random variables.

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30/06/2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30/06/2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30/06/2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30/06/2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30/06/2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %% [markdown]
# If we want to predict a variable that is not discrete, how can we do it?
#
# In classification problems, the variable is always discrete. In regression problems, the variable is always continuous.
