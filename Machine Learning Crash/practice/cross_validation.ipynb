# %% [markdown]
# # Cross Validation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import validation_curve
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %%
X = np.arange(200)/200
y = 3*(X**3)-10*(X**2)+34+np.random.randn(X.size)

plt.scatter(X,y)
plt.plot()
# Out:
# []

# %%
def PR(degree=2, **kwargs) -> LinearRegression:
    p = make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))
    return p

# %%
degree = np.arange(0,15)

train_score,val_score= validation_curve(PR(), X[:,np.newaxis], y, param_name='polynomialfeatures__degree', param_range=degree, cv=5)

# %%
train_score
# Out:
# (array([[0.        , 0.        , 0.        , 0.        , 0.        ],
#         [0.8193004 , 0.81908034, 0.85592937, 0.82817215, 0.71995666],
#         [0.82132187, 0.83740746, 0.86697871, 0.84944704, 0.74186366],
#         [0.82133178, 0.8380346 , 0.86785845, 0.84990943, 0.74274221],
#         [0.82167991, 0.83803885, 0.86840045, 0.85002614, 0.7430516 ],
#         [0.82190858, 0.84029472, 0.86913565, 0.85095214, 0.74465493],
#         [0.82211232, 0.84049609, 0.87005506, 0.85104296, 0.74475382],
#         [0.82249744, 0.84051025, 0.87107544, 0.85178643, 0.74645744],
#         [0.82471804, 0.84054324, 0.871147  , 0.85210263, 0.74700761],
#         [0.82674632, 0.84178941, 0.87117583, 0.85216865, 0.7473607 ],
#         [0.82675735, 0.8436951 , 0.87238287, 0.85237178, 0.75140759],
#         [0.82676747, 0.84369527, 0.87255561, 0.85241544, 0.75146519],
#         [0.82701233, 0.84369533, 0.87292062, 0.85328752, 0.75360459],
# ...

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
ax.plot(degree, np.median(train_score,1), color='blue', label='training score')
ax.plot(degree, np.median(val_score,1), color='red', label='validation score')
ax.legend(loc='best')
ax.set_ylim(0,1)
ax.set_xlabel('degree')
ax.set_ylabel('score')
# Out:
# Text(0, 0.5, 'score')
